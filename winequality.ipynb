# %% [markdown]
# <a href="https://colab.research.google.com/github/msandhiya07/Winequalitydb/blob/main/winequality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2 DEC 2024
# KURTOSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import plotly.express as px

# %%
df=pd.read_csv("/content/Wine_Quality_Data.csv")

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
sns.distplot(df["pH"])
# Out:
# <ipython-input-6-ff66c9686195>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["pH"])
# <Axes: xlabel='pH', ylabel='Density'>

# %%
df1=pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
sns.distplot(df1["median_house_value"])
# Out:
# <ipython-input-9-d08f580a1033>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["median_house_value"])
# <Axes: xlabel='median_house_value', ylabel='Density'>

# %%
df1["median_house_value"].mode()
# Out:
# 0    500001.0
# Name: median_house_value, dtype: float64

# %%
df1["median_house_value"].mean()
# Out:
# 207300.91235294117

# %%
from scipy.stats import norm

# %%
sns.displot(df1["median_house_value"],fit=norm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-fa51d2494763> in <cell line: 1>()
# ----> 1 sns.displot(df1["median_house_value"],fit=norm)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2191
#    2192             _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193             p.plot_univariate_histogram(**hist_kws)
#    2194
#    2195         else:
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     569
# ...

# %%
df1["median_house_value"].skew()
# Out:
# 0.9730366334725522

# %%
for i in df1.columns:
  print(i,df1[i].skew())
# Out:
# longitude -0.30400297675663496
# latitude 0.4718011203585246
# housing_median_age 0.06489403293452067
# total_rooms 4.002729998658741
# total_bedrooms 3.3226367155099132
# population 5.187211878247974
# households 3.3426683625335154
# median_income 1.6266930979614043
# median_house_value 0.9730366334725522
